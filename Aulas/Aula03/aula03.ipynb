# %% [markdown]
# # Aula 03

# %% [markdown]
# ### Introdução sobre IDEs e Git e Github
# ### Explicação sobre boas práticas, PEP 8 e uso de diretorios

# %%
print("Hello World!")

# %% [markdown]
# ## Variáveis, Expressões, Instruções

# %%
char = 'A'

type(char)
# Out:
# str
