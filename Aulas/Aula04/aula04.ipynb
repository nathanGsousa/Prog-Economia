# %% [markdown]
# ## Aula 04
#
# #### Atribuições e dicionarios, palavras-chaves (reservadas)

# %%
i = 0

while i < 10:
    print(i)
    i += 1
    print("Quantas vezes?")

print("Fim do loop")
# Out:
# 0
# Quantas vezes?
# 1
# Quantas vezes?
# 2
# Quantas vezes?
# 3
# Quantas vezes?
# 4
# Quantas vezes?
# 5
# Quantas vezes?
# 6
# Quantas vezes?
# 7
# Quantas vezes?
# 8
# Quantas vezes?
# 9
# Quantas vezes?
# Fim do loop
