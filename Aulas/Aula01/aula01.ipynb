# %% [markdown]
# # Avaliações:
# ## 3 avaliações continuas e em atividades entregues
#  1° e 2° nota: 1° Atividade e 2° Apresentação da atividade
#
#  ### Terceira nota:
#
#  Projeto de análise de dados
#
# ### Grupo para as atividades

# %% [markdown]
# # Aula 01
#
# ## Historico das linguagens de programação
